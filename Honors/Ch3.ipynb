# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation
# from numba import jit

from matplotlib import rcParams 
rcParams['text.latex.preamble'] = r'\usepackage{amsmath}' 
rcParams['text.usetex']         = True 
rcParams['font.family']         = 'sans-serif' 
rcParams['font.sans-serif']     = ['Helvetica']
rcParams['animation.html']      = 'html5'

# %matplotlib inline

# %% [markdown]
# ### Problem 3.13

# %%
def V(x,y,N=100):
    ## unitless: V = V(x,y)/V_0 | x,y = x,y/a 
    V = 0
    for n in range(N):
        V += np.exp(-(2*n+1)*np.pi*x)*np.sin((2*n+1)*np.pi*y)/(2*n+1)
        # V += np.exp(-(4*n+2)*np.pi*x)*np.sin((4*n+2)*np.pi*y)/(2*n+1)
    V *= 4/np.pi
    return V

# %%
num = 100
x = np.linspace(0.0,0.1,num) # x: 0,infinity
y = np.linspace(0.0,1.0,num) # y: 0,a
X,Y = np.meshgrid(x,y)

# %%
def plot3d(X,Y,N):
    fig, ax = plt.subplots(1,1,figsize=(7,7),subplot_kw=dict(projection='3d'))

    Z = V(X,Y,N)
    ax.plot_surface(X,Y,Z,cmap=plt.cm.coolwarm)

    ax.set_title(r'$N=%d$'%N,size=20)
    ax.set_xlabel(r'$x/a$',size=20,labelpad=15)
    ax.set_ylabel(r'$y/a$',size=20,labelpad=10)
    ax.set_zlabel(r'$V/V_0$',size=20,labelpad=10,rotation=45)
    ax.zaxis.set_rotate_label(False)
    
    ax.tick_params(axis='both',which='major',labelsize=20,direction='in')
    ax.view_init(30, 30)
    
    # plt.savefig('./plots/prob3-13_%d.png'%N,bbox_inches='tight')
    plt.show()

# %%
fps = 10
frn = 100
zarray = np.zeros([num,num,frn])

for i in range(1,frn+1):
    zarray[:,:,i-1] = V(X,Y,N=i)

# %%
def update_plot(frame_number,zarray,plot):
    plot[0].remove()
    plot[0] = ax.plot_surface(X,Y,zarray[:,:,frame_number],cmap=plt.cm.coolwarm)
    plot[1] = ax.set_title(r'$N=%d$'%frame_number,size=20)
    
fig, ax = plt.subplots(1,1,figsize=(7,7),subplot_kw=dict(projection='3d'))
ax.set_xlim(min(x),max(x))
ax.set_ylim(min(y),max(y))
ax.set_zlim(-1.3,1.3)
ax.zaxis.set_rotate_label(False)
ax.view_init(30,30)

ax.set_xlabel(r'$x/a$',size=20,labelpad=15)
ax.set_ylabel(r'$y/a$',size=20,labelpad=10)
ax.set_zlabel(r'$V/V_0$',size=20,labelpad=10)

ax.tick_params(axis='both',which='major',labelsize=20,direction='in')

plot = [ax.plot_surface(X,Y,zarray[:,:,0],cmap=plt.cm.coolwarm,rstride=1,cstride=1),
        ax.set_title(r'$N=%d$'%1,size=20)]
ani = animation.FuncAnimation(fig,update_plot,frn,fargs=(zarray,plot),interval=1000/fps)

# %%
name = './plots/animation'
ani.save(name+'.gif',writer='imagemagick',fps=fps)

# %%
# %%bash
# convert ./plots/animation.gif -fuzz 5%% -layers Optimize ./plots/animation.gif

# %% [markdown]
# ### Problem 3.16

# %%
def V(x,y,z=0.5,N=50,M=50):
    V = 0
    for n in range(N+1):
        v = 0
        for m in range(M+1):
            v += np.sin((2*m+1)*np.pi*y)*np.sinh(np.pi*np.sqrt((2*n+1)**2+(2*m+1)**2)*z)/np.sinh(np.pi*np.sqrt((2*n+1)**2+(2*m+1)**2))/(2*m+1)
        v *= np.sin((2*n+1)*np.pi*x)/(2*n+1)
        V += v
    V *= 16/np.pi**2
    return V

# %%
num = 100
x = np.linspace(0.0,1.0,num) # x: 0,infinity
y = np.linspace(0.0,1.0,num) # y: 0,a
X,Y = np.meshgrid(x,y)

# %%
def plot3d(X,Y,z):
    fig, ax = plt.subplots(1,1,figsize=(7,7),subplot_kw=dict(projection='3d'))

    ax.plot_surface(X,Y,V(X,Y,z),cmap=plt.cm.coolwarm)

    ax.set_title(r'$z=%.1f$'%z,size=20)
    ax.set_xlabel(r'$x/a$',size=20,labelpad=15)
    ax.set_ylabel(r'$y/a$',size=20,labelpad=10)
    ax.set_zlabel(r'$V/V_0$',size=20,labelpad=20,rotation=45)
    ax.zaxis.set_rotate_label(False)
    
    ax.tick_params(axis='both',which='major',labelsize=20,direction='in')
    ax.view_init(30, -60)
    
    plt.savefig('./plots/prob3-16_%s.png'%str(round(z,2)).replace('.','-'),bbox_inches='tight')
    plt.show()

# %%
z = np.linspace(0.0,1.0,6)
print(z)
for _ in z:
    plot3d(X,Y,_)

# %%
def summ(x):
    res = 0
    for n in range(10):
        res += np.sin((2*n+1)*x)/(2*n+1)
    return res*4/np.pi
print(summ(np.linspace(0.0,1.0,10))**2)

# %% [markdown]
# ### Finite Difference and Relaxation

# %%
def E_from_V(V):
    shape = np.shape(V)
    Ex = np.zeros(shape)
    Ey = np.zeros(shape)
    h = X[0,1]-X[0,0]
    for i in range(1,shape[0]-1):
        for j in range(1,shape[1]-1):
            if (Y[i,j] >= 0.25 and Y[i,j] <= 0.75) and ((X[i,j] >= 0.2 and X[i,j] <= 0.3) or (X[i,j] >= 0.7 and X[i,j] <= 0.8)):
                continue
            Ex[i,j] = -(V[i,j+1] - V[i,j-1])/2.0/h
            Ey[i,j] = -(V[i+1,j] - V[i-1,j])/2.0/h
    return Ex,Ey

# %%
# @jit(nopython=True)
def update(V):
    V_new = np.copy(V)
    shape = np.shape(V)
    h = X[0,1]-X[0,0]
    for i in range(1,shape[0]-1):
        for j in range(1,shape[1]-1):
            if (Y[i,j] >= 0.25 and Y[i,j] <= 0.75) and ((X[i,j] >= 0.2 and X[i,j] <= 0.3) or (X[i,j] >= 0.7 and X[i,j] <= 0.8)):
                continue
            V_new[i,j]  = (V[i+1,j] + V[i-1,j] + V[i,j+1] + V[i,j-1])/4.0
    return V_new

# %%
def plot3d(X,Y,V,N=-1):
    fig, ax = plt.subplots(1,1,figsize=(7,7),subplot_kw=dict(projection='3d'))

    ax.plot_surface(X,Y,V,cmap=plt.cm.coolwarm)

    ax.set_xlabel(r'$x/a$',size=20,labelpad=15)
    ax.set_ylabel(r'$y/a$',size=20,labelpad=10)
    ax.set_zlabel(r'$V/V_0$',size=20,labelpad=15,rotation=45)
    ax.zaxis.set_rotate_label(False)
    if N >= 0:
        ax.set_title(r'$N=%d$'%N,size=20)
    ax.set_title('Parallel plate capacitor',size=30)
    
    ax.tick_params(axis='both',which='major',labelsize=20,direction='in')
    ax.view_init(30,30)
    
    # plt.savefig('./plots/prob3-13_%d.png'%N,bbox_inches='tight')
    plt.show()

# %%
N = 10 # defines grid spacing
x = np.linspace(0.0,1.0,N)
y = np.linspace(0.0,1.0,N)

X,Y = np.meshgrid(x,y)
V = np.zeros(np.shape(X))

def initial(x,y):
    if (y >= 0.25 and y <= 0.75):
        if (x >= 0.2 and x <= 0.3):
            return 1.0
        elif x >= 0.7 and x <= 0.8:
            return -1.0
        else:
            return 0.0
    else:
        return 0.0
    
def set_initial(shape):
    V = np.zeros(shape)
    for i in range(shape[0]):
        for j in range(shape[1]):
            V[i,j] = initial(X[i,j],Y[i,j])
    return V

V = set_initial(np.shape(X))
# plot3d(X,Y,V)
# print(X)
# print(Y)
# print(V)

i = 0
while True:
    i += 1
    V_new = update(V)
    if np.all(abs(V_new - V) < 1e-5):
        print(i)
        break
    V = V_new
plot3d(X,Y,V)
# Out:
# 44

# %%
Ex_vac,Ey_vac = E_from_V(V)

# %%
plt.quiver(Ex_vac,Ey_vac)

# %% [markdown]
# ### Finite Difference and Relaxation with Dielectrics

# %%
def eps_f(x,y):
    if (y >= 0.25 and y <= 0.75) and (x >= 0.3 and x <= 0.7):
        return 4.0
    else:
        return 1.0

# %%
# @jit(nopython=True)
def update(V):
    V_new = np.copy(V)
    shape = np.shape(V)
    h = X[0,1]-X[0,0]
    for i in range(1,shape[0]-1):
        for j in range(1,shape[1]-1):
            if (Y[i,j] >= 0.25 and Y[i,j] <= 0.75) and ((X[i,j] >= 0.2 and X[i,j] <= 0.3) or (X[i,j] >= 0.7 and X[i,j] <= 0.8)):
                continue
            eps = np.array([[0.0,0.0],[0.0,0.0]])
            eps[0][0] = eps_f(X[i,j]-h/2,Y[i,j]+h/2)
            eps[0][1] = eps_f(X[i,j]+h/2,Y[i,j]+h/2)
            eps[1][0] = eps_f(X[i,j]-h/2,Y[i,j]-h/2)
            eps[1][1] = eps_f(X[i,j]+h/2,Y[i,j]-h/2)
            a0 = np.sum(eps)
            a3,a1 = 0.5*np.sum(eps,axis=0)
            a2,a4 = 0.5*np.sum(eps,axis=1)
            V_new[i,j] = (a1*V[i,j+1] + a2*V[i+1,j] + a3*V[i,j-1] + a4*V[i-1,j])/a0
            #V_new[i,j]  = (V[i+1,j] + V[i-1,j] + V[i,j+1] + V[i,j-1])/4.0
            #V_new[i,j] += ((eps[i+1,j]-eps[i-1,j])*(V[i+1,j] - V[i-1,j]) + (eps[i+1,j]-eps[i-1,j])*(V[i+1,j] - V[i-1,j]))*h/8.0/eps[i,j]
    return V_new

# %%
def plot3d(X,Y,V,N=-1):
    fig, ax = plt.subplots(1,1,figsize=(7,7),subplot_kw=dict(projection='3d'))

    ax.plot_surface(X,Y,V,cmap=plt.cm.coolwarm)

    ax.set_xlabel(r'$x/a$',size=20,labelpad=15)
    ax.set_ylabel(r'$y/a$',size=20,labelpad=10)
    ax.set_zlabel(r'$V/V_0$',size=20,labelpad=15,rotation=45)
    ax.zaxis.set_rotate_label(False)
    if N >= 0:
        ax.set_title(r'$N=%d$'%N,size=20)
    ax.set_title('Parallel plate capacitor',size=30)
    
    ax.tick_params(axis='both',which='major',labelsize=20,direction='in')
    ax.view_init(30,30)
    
    # plt.savefig('./plots/prob3-13_%d.png'%N,bbox_inches='tight')
    plt.show()

# %%
# N = 20 # defines grid spacing
x = np.linspace(0.0,1.0,N)
y = np.linspace(0.0,1.0,N)

X,Y = np.meshgrid(x,y)
V = np.zeros(np.shape(X))

def initial(x,y):
    if (y >= 0.25 and y <= 0.75):
        if (x >= 0.2 and x <= 0.3):
            return 1.0
        elif x >= 0.7 and x <= 0.8:
            return -1.0
        else:
            return 0.0
    else:
        return 0.0
    
def set_initial(shape):
    V = np.zeros(shape)
    for i in range(shape[0]):
        for j in range(shape[1]):
            V[i,j] = initial(X[i,j],Y[i,j])
    return V

V = set_initial(np.shape(X))
# plot3d(X,Y,V)
# print(X)
# print(Y)
# print(V)

i = 0
while True:
    i += 1
    V_new = update(V)
    if np.all(abs(V_new - V) < 1e-5):
        print(i)
        break
    V = V_new
plot3d(X,Y,V)
# Out:
# 48

# %%
Ex,Ey = E_from_V(V)

fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(7*2,7))
ax[0].quiver(X,Y,Ex_vac,Ey_vac,scale=N,scale_units='inches')
ax[1].quiver(X,Y,Ex,Ey,scale=N,scale_units='inches')

ax[0].set_title('Vacuum field',size=20)
ax[0].set_xlabel(r'$x/a$',size=20)
ax[1].set_ylabel(r'$y/a$',size=20)
ax[1].set_xlabel(r'$x/a$',size=20)
ax[1].set_title(r'With dielectric: $e_r = 2.0$',size=20)

plt.show()
fig.savefig('plots/Efield_er-2.pdf',bbox_inches='tight')

# %%
# np.set_printoptions(precision=3)
np.sqrt(Ex**2.0 + Ey**2.0)/np.sqrt(Ex_vac**2.0 + Ey_vac**2.0)
# Out:
# /tmp/ipykernel_98191/1882619112.py:2: RuntimeWarning: invalid value encountered in true_divide
#   np.sqrt(Ex**2.0 + Ey**2.0)/np.sqrt(Ex_vac**2.0 + Ey_vac**2.0)
# array([[  nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,
#           nan],
#        [  nan, 0.962, 0.955, 0.829, 0.835, 0.856, 0.83 , 0.957, 0.965,
#           nan],
#        [  nan, 0.976, 1.011, 0.825, 0.81 , 0.789, 0.796, 1.01 , 0.977,
#           nan],
#        [  nan, 1.001,   nan, 1.026, 0.71 , 0.678, 1.006,   nan, 1.001,
#           nan],
#        [  nan, 1.   ,   nan, 1.077, 0.697, 0.664, 1.056,   nan, 1.   ,
#           nan],
#        [  nan, 1.   ,   nan, 1.077, 0.697, 0.664, 1.056,   nan, 1.   ,
#           nan],
#        [  nan, 1.001,   nan, 1.026, 0.71 , 0.678, 1.006,   nan, 1.001,
#           nan],
#        [  nan, 0.976, 1.011, 0.825, 0.81 , 0.789, 0.796, 1.01 , 0.977,
#           nan],
#        [  nan, 0.962, 0.955, 0.829, 0.835, 0.856, 0.83 , 0.957, 0.965,
#           nan],
#        [  nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,
#           nan]])
